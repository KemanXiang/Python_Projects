# %% [markdown]
# # Dash Basics: HTML and Core Components

# %% [markdown]
# ### Objectives
#
# -   Create a dash application layout
# -   Add HTML H1, P, and Div components
# -   Add core graph component
# -   Add multiple charts
#
# ### Dataset Used
#
# [Airline Reporting Carrier On-Time Performance](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv)

# %% [markdown]
# ## Goal
#
# Create a dashboard that displays the percentage of flights running under specific distance group. Distance group is the distance intervals, every 250 miles, for flight segment. If the flight covers to 500 miles, it will be under distance group 2 (250 miles + 250 miles).
#
# ### Expected Output
#
# Below is the expected result from the lab. Our dashboard application consists of three components:
#
# - Title of the application
# - Description of the application
# - Chart conveying the proportion of distance group by month
#
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/basics_output.png)
#
# ### To do:
#
# 1.  Import required libraries and read the dataset
# 2.  Create an application layout
# 3.  Add title to the dashboard using HTML H1 component
# 4.  Add a paragraph about the chart using HTML P component
# 5.  Add the pie chart above using core graph component
# 6.  Run the app

# %% [markdown]
# Install python packages required to run the application

# %%
pip install packaging
# Out:
# Requirement already satisfied: packaging in /Applications/anaconda3/lib/python3.13/site-packages (24.2)
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLCertVerificationError('“pypi.org” certificate is not standards compliant'))) - skipping
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Applications/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Applications/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Applications/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Applications/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLCertVerificationError('“pypi.org” certificate is not standards compliant'))) - skipping

# %%
pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org dash
# Out:
# Collecting dash
#   Downloading dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (3.1.0)
# Requirement already satisfied: Werkzeug<3.2 in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (8.5.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (4.12.2)
# Requirement already satisfied: requests in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (72.1.0)
# Collecting janus>=1.0.0 (from dash)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic>=2.10 in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (2.11.7)
# Requirement already satisfied: comm in /Applications/anaconda3/lib/python3.13/site-packages (from dash) (0.2.1)
# Requirement already satisfied: Jinja2>=3.1.2 in /Applications/anaconda3/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in /Applications/anaconda3/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /Applications/anaconda3/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from Flask<3.2,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from Werkzeug<3.2->dash) (3.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from plotly>=5.0.0->dash) (9.0.0)
# Requirement already satisfied: packaging in /Applications/anaconda3/lib/python3.13/site-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->dash) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->dash) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic>=2.10->dash) (0.4.0)
# Requirement already satisfied: traitlets>=4 in /Applications/anaconda3/lib/python3.13/site-packages (from comm->dash) (5.14.3)
# Requirement already satisfied: zipp>=3.20 in /Applications/anaconda3/lib/python3.13/site-packages (from importlib-metadata->dash) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Applications/anaconda3/lib/python3.13/site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests->dash) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Applications/anaconda3/lib/python3.13/site-packages (from requests->dash) (2025.8.3)
# Downloading dash-4.4.1-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 5.7 MB/s eta 0:00:00a 0:00:01
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: retrying, janus, dash
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [dash]2/3 [dash]
# Successfully installed dash-4.4.1 janus-2.0.0 retrying-1.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /Applications/anaconda3/lib/python3.13/site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /Applications/anaconda3/lib/python3.13/site-packages (from plotly) (24.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Part 1 - Data Preparation

# %%
# Import required packages
import pandas as pd
import plotly.express as px
import dash
from dash import dcc
from dash import html

# %%
# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})

# %%
# Randomly sample 500 data points. Setting the random state to be 42 so that we get same result.
data = airline_data.sample(n=500, random_state=42)

# %%
# Pie Chart Creation
fig = px.pie(data, values='Flights', names='DistanceGroup', title='Distance group proportion by flights')

# %% [markdown]
# ## Part 2 - Create dash application and get the layout skeleton
#
# Next, we create a skeleton for our dash application. Our dashboard application has three components as seen before:
#
# - Title of the application
# - Description of the application
# - Chart conveying the proportion of distance group by month
#
# Mapping to the respective Dash HTML tags:
#
# - Title added using `html.H1()` tag
# - Description added using `html.P()` tag
# - Chart added using `dcc.Graph()` tag

# %%
# Create a dash application
app = dash.Dash(__name__)

# Get the layout of the application and adjust it.
# Create an outer division using html.Div and add title to the dashboard using html.H1 component
# Add description about the graph using HTML P (paragraph) component
# Finally, add graph component.
app.layout = html.Div(children=[html.H1('Airline Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
                                html.P('Proportion of distance group (250 mile distance interval group) by flights.', 
                                       style={'textAlign':'center', 'color': '#F57241'}),
                                dcc.Graph(figure=fig),
                                               
                    ])

# Run the application                   
if __name__ == '__main__':
    app.run()
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# The app will show like below:
#
# ![](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/labs/Module%204/images/lab1_output.png)
