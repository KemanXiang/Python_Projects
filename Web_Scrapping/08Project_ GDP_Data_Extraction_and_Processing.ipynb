# %% [markdown]
# # Project: GDP Data extraction and processing
#
# ## Introduction
#
# In this project, we will extract data from a website using webscraping and reqeust APIs process it using Pandas and Numpy libraries.

# %% [markdown]
# ## Project Scenario:
#
# Let's assume that an international firm that is looking to expand its business in different countries across the world has recruited us. We have been hired as junior Data Engineer and are tasked with creating a script that can extract the list of the top 10 largest economies of the world in descending order of their GDPs in Billion USD (rounded to 2 decimal places), as logged by the International Monetary Fund (IMF).
#
# The required data seems to be available on the URL mentioned below:

# %% [markdown]
# URL: https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29

# %% [markdown]
# ## Objectives
#
#  - Use Webscraping to extract required information from a website.
#  - Use Pandas to load and process the tabular data as a dataframe.
#  - Use Numpy to manipulate the information contatined in the dataframe.
#  - Load the updated dataframe to CSV file.

# %% [markdown]
# ---

# %% [markdown]
# # Setup

# %% [markdown]
# For this project, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.

# %%
#Install required packages
# !pip install pandas numpy 
# !pip install lxml
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 116.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 110.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd

# Suppress warnings generated by the code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ---

# %% [markdown]
# ### Part 1
# Extract the required GDP data from the given URL using Web Scraping.

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %% [markdown]
# We can use Pandas library to extract the required table directly as a DataFrame. Note that the required table is the third one on the website, as shown in the image below.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/images/pandas_wbs_3.png">

# %%
# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
tables = pd.read_html(URL)
df = tables[3]
#print(df)

# Replace the column headers with column numbers
df.columns = range(df.shape[1])
#print(df)

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
country_GDP = df[[0,2]]
#print(country_GDP)

# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
top10_country_GDP = country_GDP.iloc[1:11,:]
#print(top10_country_GDP)

# Assign column names as "Country" and "GDP (Million USD)"
top10_country_GDP.columns = ["Country","GDP (Million USD)"]
print(top10_country_GDP)
# Out:
#            Country GDP (Million USD)
# 1    United States          26854599
# 2            China          19373586
# 3            Japan           4409738
# 4          Germany           4308854
# 5            India           3736882
# 6   United Kingdom           3158938
# 7           France           2923489
# 8            Italy           2169745
# 9           Canada           2089672
# 10          Brazil           2081235

# %% [markdown]
# ### Part 2
# Modify the GDP column of the DataFrame, converting the value available in Million USD to Billion USD. Use the `round()` method of Numpy library to round the value to 2 decimal places. Modify the header of the DataFrame to `GDP (Billion USD)`.

# %%
# Change the data type of the 'GDP (Million USD)' column to integer. Use astype() method.
top10_country_GDP["GDP (Million USD)"] = top10_country_GDP["GDP (Million USD)"].astype(int)

# Convert the GDP value in Million USD to Billion USD
top10_country_GDP[["GDP (Million USD)"]] = top10_country_GDP[["GDP (Million USD)"]] / 1000
#print(top10_country_GDP[["GDP (Million USD)"]])

# Use numpy.round() method to round the value to 2 decimal places.
top10_country_GDP[["GDP (Million USD)"]] = np.round(top10_country_GDP[["GDP (Million USD)"]],decimals = 2)
#print(top10_country_GDP[["GDP (Million USD)"]])

# Rename the column header from 'GDP (Million USD)' to 'GDP (Billion USD)'
top10_country_GDP.columns = ["Country","GDP (Billion USD)"]
# OR df.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})
print(top10_country_GDP)
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %% [markdown]
# ### Part 3

# %% [markdown]
# Load the DataFrame to the CSV file named "Largest_economies.csv"

# %%
# Load the DataFrame to the CSV file named "Largest_economies.csv"
top10_country_GDP.to_csv("./Largest_economies.csv")

# %% [markdown]
# ---
