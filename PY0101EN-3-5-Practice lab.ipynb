# %% [markdown]
# <center>
#
# # **Projext: Text Analysis - Basic Natual Language Processing**
#
# </center>

# %% [markdown]
# # What is text analysis?
# Text analysis, also known as text mining or text analytics, refers to the process of extracting meaningful information and insights from textual data.

# %% [markdown]
# ## Objectives
# - Use Python commands to perform text analysis.
# - Convert the text to lowercase and then find and count the frequency of all unique words, as well as a specified word.

# %% [markdown]
# ## Setup

# %% [markdown]
# For this project, we will be using the following data types:
# * List
# * Strings
# * Classes and objects

# %% [markdown]
# **Let's consider a real-life scenario where we are analyzing customer feedback for a product. We have a large data set of customer reviews in the form of strings, and we want to extract useful information from them using the three identified tasks:**
#
# **Task 1. String in lowercase:**
# We want to pre-process the customer feedback by converting all the text to lowercase. This step helps standardize the text. Lower casing the text allows us to focus on the content rather than the specific letter casing.
#
# **Task 2. Frequency of all words in a given string:**
# After converting the text to lowercase, we want to determine the frequency of each word in the customer feedback. This information will help us identify which words are used more frequently, indicating the key aspects or topics that customers are mentioning in their reviews. By analyzing the word frequencies, we can gain insights into the most common issues raised by customers.
#
# **Task 3. Frequency of a specific word:**
# In addition to analyzing the overall word frequencies, we want to specifically track the frequency of a particular word that is relevant to our analysis. For example, we might be interested in monitoring how often the word "reliable" appears in customer reviews to gauge customer sentiment about the product's reliability. By focusing on the frequency of a specific word, we can gain a deeper understanding of customer opinions or preferences related to that particular aspect.
#
# By performing these tasks on the customer feedback dataset, we can gain valuable insights into customer sentiment

# %% [markdown]
# ----

# %% [markdown]
# <center>
#
# # Part-A

# %% [markdown]
# <center>
#
# **Note: In Part-A, we would not be getting any output as we are just storing the string and creating a class.**
#     </center>

# %% [markdown]
# ## Step 1: Define a string
# "Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet." <br>

# %%
givenstring="Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet."

# %% [markdown]
# ### To achieve the tasks mentioned in the scenario, we need to create a class with three different methods.

# %% [markdown]
# ## Step 2: Define the class and its attributes

# %% [markdown]
# 1. Create a class named TextAnalyzer.
# 2. Define the constructor `__init__` method that takes a text argument.

# %%
# Please do not run this code cell as it is incomplete and will produce an error.

# Let's create a class called TextAnalyzer to analyze text.
class TextAnalyzer(object):
    # The __init__ method initializes the class with a 'text' parameter.
    # You will store the provided 'text' as an instance variable.
    def __init__(self, text):

# %% [markdown]
# ----

# %% [markdown]
# ## Step 3: Implement a code to format the text in lowercase

# %% [markdown]
# 1. Inside the constructor, convert the text argument to lowercase using the `lower()` method.
# 2. Then, remove punctuation marks (periods, exclamation marks, commas, and question marks) from the text using the `replace()` method.
# 3. Finally, assign the formatted text to a new attribute called fmtText.
#
# **Here we will be updating the above `TextAnalyzer` class with the points mentioned above.**

# %%
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace(',','').replace('.','').replace('!','').replace('?','')
        # make text lowercase
        formattedText = formattedText.lower()
        self.fmtText = formattedText

# %% [markdown]
# ----

# %% [markdown]
# ## Step 4: Implement a code to count the frequency of all unique words

# %% [markdown]
# * In this step, we will implement the `freqAll()` method with the below parameters:
#      1. Split the fmtText attribute into individual words using the `split()` method.
#      2. Create an empty dictionary to store the word frequency.
#      3. Iterate over the list of words and update the frequency dictionary accordingly.
#      4. Use `count` method for counting the occurence.
#      5. Return the frequency dictionary.
#
# **Update the above `TextAnalyzer` class with points mentioned above.**

# %%
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # remove punctuation
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        # make text lowercase
        formattedText = formattedText.lower()
        self.fmtText = formattedText
  
    def freqAll(self):        
        # split text into words
        sptText = self.fmtText.split()
        # Create dictionary
        word_fre = {}
        for key in set(sptText):   # ! use set to remove duplicates in list
            word_fre[key] = sptText.count(key)
        return word_fre

# %% [markdown]
# ----

# %% [markdown]
# ## Step 5: Implement a code to count the frequency of a specific word

# %% [markdown]
# In step-5, we have to implement the `freqOf(word)` method that takes a word argument:
#    1. Create a method and pass the word that needs to be found.
#    2. Get the `freqAll` method to look for count and check if that word is in the list.
#    3. Return the count. If the word is not found, the count returned is 0.
#
# **Update the above `TextAnalyzer` class with the points mentioned above.**

# %%
class TextAnalyzer(object):
    
    def __init__ (self, text):
        formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
        # make text lowercase
        formattedText = formattedText.lower()
        self.fmtText = formattedText
        
    def freqAll(self):        
        # split text into words
        sptText = self.fmtText.split()
        # Create dictionary
        word_fre = {}
        for key in set(sptText):   # ! use set to remove duplicates in list
            word_fre[key] = sptText.count(key)
        return word_fre
           
    def freqOf(self,word):
        # get frequency map
        freqDict = self.freqAll() # Get the freqAll method
        
        if word in freqDict:
            return freqDict[word]
        else:
            return 0

# %% [markdown]
# ### Now, we have successfully created a class with three methods.

# %% [markdown]
# <center>
#
# # Part-B

# %% [markdown]
# <center>
#
# **In Part B, we will call the functions created in Part A, allowing the functions to execute and generate output.**
#     </center>

# %% [markdown]
# ## Step 1: Create an instance of TextAnalyzer class
# * Instantiate the TextAnalyzer class by passing the given string as an argument.

# %%
text = TextAnalyzer(givenstring)

# %% [markdown]
# ## Step 2: Call the function that converts the data into lowercase

# %%
text.fmtText
# Out:
# 'lorem ipsum dolor diam amet consetetur lorem magna sed diam nonumy eirmod tempor diam et labore et diam magna et diam amet'

# %% [markdown]
# We have successfully converted string into lowercase.

# %% [markdown]
# ## Step 3: Call the function that counts the frequency of all unique words from the data

# %%
text.freqAll()
# Out:
# {'consetetur': 1,
#  'nonumy': 1,
#  'labore': 1,
#  'tempor': 1,
#  'sed': 1,
#  'ipsum': 1,
#  'magna': 2,
#  'eirmod': 1,
#  'diam': 5,
#  'dolor': 1,
#  'et': 3,
#  'lorem': 2,
#  'amet': 2}

# %% [markdown]
# We have successfully calculated the frequency of all unique words in the string.

# %% [markdown]
# ## Step 4: Call the function that counts the frequency of a specific word
# Here, we will call the function that counts the frequency of the word "lorem".
# <br>

# %%
text.freqOf('lorem')
# Out:
# 2

# %% [markdown]
# We have successfully calculated the frequency of all specified words.

# %% [markdown]
# ----

# %% [markdown]
# <!--
# ## Change Log
# -->

# %% [markdown]
# <!--
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-11-05|0.4|Abhishek Gagneja| Updated lab instructions|
# |2023-05-17|0.3|Akansha yadav| Created lab under maintenance|
# |2020-07-17|0.1|Sam     |Create Lab Template|
# |2022-11-19|0.2|Shengkai|Update Lab Template|
# -->
